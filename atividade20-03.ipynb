# %%
pip install pandas

# %%
import pandas as pd

# %%
data =  {'marca': ['Samsung', 'Aple', 'Xiaomi', 'Motorola'],
         'modelo': ['galaxy s20 fe', 'iphone 12', 'redmi note 10', 'moto g power'],
         'preço':['2.999$', '3.9999$', '1.200$','1.700$'],
         'Quantidade':['390', '460', '278', '759' ]}

df  = pd.DataFrame(data)

print(df)
# Out:
#       marca         modelo    preço Quantidade
# 0   Samsung  galaxy s20 fe   2.999$        390
# 1      Aple      iphone 12  3.9999$        460
# 2    Xiaomi  redmi note 10   1.200$        278
# 3  Motorola   moto g power   1.700$        759

# %%
data  = {'Produto': ['Shampoo', 'Sabonete', 'Creme dental'],
         'Marca': ['Johnson & Johnson', 'Protex', 'Colgate'],
         'Peso': ['500ml', '5g', '3g'],
         'Preço':['30$', '2$', '10$']}

df = pd.DataFrame(data)

print(df)
# Out:
#         Produto              Marca   Peso Preço
# 0       Shampoo  Johnson & Johnson  500ml   30$
# 1      Sabonete             Protex     5g    2$
# 2  Creme dental            Colgate     3g   10$

# %%
df['Quantidade'] = [7, 9, 10]

print(df)
# Out:
#         Produto              Marca   Peso Preço  Quantidade
# 0       Shampoo  Johnson & Johnson  500ml   30$           7
# 1      Sabonete             Protex     5g    2$           9
# 2  Creme dental            Colgate     3g   10$          10
