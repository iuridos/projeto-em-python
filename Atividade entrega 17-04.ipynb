# %%
pip install pandas

# %%
import pandas as pd

# %%
data = {
    "Produto": ["Biscoito", "Chocolate", "Manteiga", "Arroz", "Feijão", "Jack Daniels", "Red Label"],
    "Quantidade": [20, 30, 40, 50, 68, 20, 30],
    "Produtos Vendidos": [1000, 5000, 8000, 2000, 100, 50, 100],
    "Preços": [3.00, 7.00, 8.00, 21.00, 11.00, 160.00, 120.00]
    }

df = pd.DataFrame(data)
print(df)
# Out:
#         Produto  Quantidade  Produtos Vendidos  Preços
# 0      Biscoito          20               1000     3.0
# 1     Chocolate          30               5000     7.0
# 2      Manteiga          40               8000     8.0
# 3         Arroz          50               2000    21.0
# 4        Feijão          68                100    11.0
# 5  Jack Daniels          20                 50   160.0
# 6     Red Label          30                100   120.0

# %%
df.loc[df["Produtos Vendidos"]>1000]
# Out:
#      Produto  Quantidade  Produtos Vendidos  Preços
# 1  Chocolate          30               5000     7.0
# 2   Manteiga          40               8000     8.0
# 3      Arroz          50               2000    21.0
