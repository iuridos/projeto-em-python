# %%
def calcular_imc(altura,peso):return peso/(altura**2)

altura=(input("Digite sua altura em metros"))peso=(input("Digite seu peso em kg:"))

imc=calcular_imc(altura,peso)

print("Seu IMC é:"imc)
# Out:
#   File "<ipython-input-2-ed925a5f30b4>", line 3
#     altura=(input("Digite sua altura em metros"))peso=(input("Digite seu peso em kg:"))
#                                                  ^
# SyntaxError: invalid syntax
