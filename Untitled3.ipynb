# %%
#1

#variaveis
custo = float(input("Qual o valor do almoço? "))
categoria = input("Em qual categeoria voce se enquadra? ")

if categoria == "Segunda compra":
  Desconto  = custo * 0.09
elif categoria  ==  "Estudante":
  Desconto  = custo * 0.15
elif categoria == "Professor":
  Desconto = custo * 0.18
else:
  print("Desconto não encontrado")

valor_final = custo - Desconto
# Out:
# Qual o valor do almoço? 30
# Em qual categeoria voce se enquadra? estudante
# Desconto não encontrado
