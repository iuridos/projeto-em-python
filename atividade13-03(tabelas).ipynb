# %%
pip install pandas

# %%
import pandas as pd

# %%
data = {'Nome': ['Alice', 'Bob', 'Charlie'],
       'Idade': [25, 30, 35],
       'Cidade': ['São paulo', 'Rio de Janeiro', 'Curitiba']}

df = pd.DataFrame(data)

# %%
print(df)
# Out:
#       Nome  Idade          Cidade
# 0    Alice     25       São paulo
# 1      Bob     30  Rio de Janeiro
# 2  Charlie     35        Curitiba

# %%
df.describe()
# Out:
#        Idade
# count    3.0
# mean    30.0
# std      5.0
# min     25.0
# 25%     27.5
# 50%     30.0
# 75%     32.5
# max     35.0

# %%
df.head()
# Out:
#       Nome  Idade          Cidade
# 0    Alice     25       São paulo
# 1      Bob     30  Rio de Janeiro
# 2  Charlie     35        Curitiba

# %%
df['Notas'] =[10, 9, 8]

print(df)
# Out:
#       Nome  Idade          Cidade  Notas
# 0    Alice     25       São paulo     10
# 1      Bob     30  Rio de Janeiro      9
# 2  Charlie     35        Curitiba      8
